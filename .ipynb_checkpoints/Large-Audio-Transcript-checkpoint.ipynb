# %% [markdown]
# # Large Audio Files

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
path = 'tedtalk1.wav'

# %%
f = open("transcript-large.txt", "w+")
f.write(get_large_audio_transcription(path))
f.close()
# Out:
# Error:
# audio-chunks/chunk2.wav : Sewing college.
# audio-chunks/chunk3.wav : I was a government made.
# audio-chunks/chunk4.wav : Which means i had to write a lot of papers.
# audio-chunks/chunk5.wav : Now on a normal student write to people in the work out of it like this.
# audio-chunks/chunk6.wav : Say now.
# audio-chunks/chunk7.wav : Just started digital slowly you can often the first week that have your days later on.
# audio-chunks/chunk8.wav : Everything i've done things taste civil.
# audio-chunks/chunk9.wav : I would want to do that like that.
# audio-chunks/chunk10.wav : That would be the plan i would i would have it already to go but that's the people come along and then i can do this.
# Error:
# audio-chunks/chunk12.wav : And i want happening everything on paper.
# audio-chunks/chunk13.wav : But then came my 90 page senior thesis.
# audio-chunks/chunk14.wav : Paperless post.
# audio-chunks/chunk15.wav : Any for people like that i normal workflow was not an option it was way too big.
# audio-chunks/chunk16.wav : Paintings outlets.
# audio-chunks/chunk17.wav : Had to go something like this.
# audio-chunks/chunk18.wav : Saturday yoga so i start off light.
# audio-chunks/chunk19.wav : And i pump it up in the middle months.
# audio-chunks/chunk20.wav : And then the end i will pick it up the high gears staircase how hard it just walk up the stairs.
# audio-chunks/chunk21.wav : No big deal right.
# audio-chunks/chunk22.wav : Advanced funniest thing happened there's first few months.
# audio-chunks/chunk23.wav : The cayman went and i couldn't quite do stuff.
# audio-chunks/chunk24.wav : Swindon arson new revised plan.
# audio-chunks/chunk25.wav : Men.
# audio-chunks/chunk26.wav : Middleman factual went by.
# audio-chunks/chunk27.wav : And i didn't really write words.
# audio-chunks/chunk28.wav : And so we're here.
# audio-chunks/chunk29.wav : And then 2 months turned into one man.
# audio-chunks/chunk30.wav : Shared into 2 weeks.
# audio-chunks/chunk31.wav : Monday woke up.
# audio-chunks/chunk32.wav : 3 days until the deadline.
# audio-chunks/chunk33.wav : Still not having written the word and sorry to the only thing i could.
# audio-chunks/chunk34.wav : I wrote 90 pages over 72 hours pulling that one but two all-nighters.
# audio-chunks/chunk35.wav : Humans are not supposed to pull two all-nighters.
# audio-chunks/chunk36.wav : Sprint across campus.
# audio-chunks/chunk37.wav : Dolphin slow motion and garden just of the deadline.
# audio-chunks/chunk38.wav : That was the end of every.
# audio-chunks/chunk39.wav : But a week later i get a call.
# audio-chunks/chunk40.wav : School.
# audio-chunks/chunk41.wav : And they say this tomorrow and i say yeah.
# audio-chunks/chunk42.wav : And they say we need to talk about your thesis.
# audio-chunks/chunk43.wav : I say ok.
# audio-chunks/chunk44.wav : And they say.
# audio-chunks/chunk45.wav : The best one we've ever seen.
# Error:
# Error:
# audio-chunks/chunk48.wav : That did not.
# audio-chunks/chunk49.wav : Is a very very bad jesus i just.
# audio-chunks/chunk50.wav : Wanted to enjoy that one moment when all of you fat this guy is amazing no no it's very very bad.
# Error:
# audio-chunks/chunk52.wav : Anyway today i'm a writer or blogger guy i write the blog wait but why.
# audio-chunks/chunk53.wav : And couple years ago i decided to write about the crafting.
# audio-chunks/chunk54.wav : The heaters always perplexed the non procrastinators around me and i wanted to explain the non procrastinators of the world.
# audio-chunks/chunk55.wav : What goes on in the head the procrastinators while we are there we are.
# audio-chunks/chunk56.wav : Did the brains procrastinators for actually different than the brains of other people.
# audio-chunks/chunk57.wav : And test this i found an mri lad that actually let me scan both my brain and brain of a proven on procrastinate.
# audio-chunks/chunk58.wav : And i try to compare them and i actually brought them here to show you today and i want you take a look carefully the see if you can notice a difference and i know that if you had a train brain expert not that obviously just take a look ok.
# audio-chunks/chunk59.wav : So here's the brain of a non procrastinator.
# Error:
# audio-chunks/chunk61.wav : Now.
# audio-chunks/chunk62.wav : Use my brain.
# Error:
# audio-chunks/chunk64.wav : There is a difference.
# audio-chunks/chunk65.wav : Both brains have a rational decision maker in the brain also has an instant gratification.
# audio-chunks/chunk66.wav : What is this name for the procrastinator.
# audio-chunks/chunk67.wav : Everything's fine until this happened.
# audio-chunks/chunk68.wav : So the rational decision maker will make the rational decision to do something productive but he doesn't like that.
# audio-chunks/chunk69.wav : Takes the wheel and he says actually works with the entire wikipedia page of the nancy kerrigan tonya harding skin looks i just remember that happy.
# audio-chunks/chunk70.wav : Then over the fridge received anything new in there since 10 minutes ago.
# audio-chunks/chunk71.wav : After that we're gonna go on a youtube spiral that starts with videos of richard feynman talking about magnets and ends much much later with us watching interviews of justin bieber's mum.
# Error:
# audio-chunks/chunk73.wav : All that's going to take a while so when i could really have room on the schedule for any work today sorry.
# Error:
# audio-chunks/chunk75.wav : What is going on here.
# audio-chunks/chunk76.wav : Instagram vacation monkey does not seem like a guy want behind the wheel he was entirely in the present moment he has no memory of the past.
# audio-chunks/chunk77.wav : No no what the future is like tooth.
# audio-chunks/chunk78.wav : Easy and fun.
# audio-chunks/chunk79.wav : Now and the animal world.
# audio-chunks/chunk80.wav : That works fine if your dog and you spend your whole life doing nothing other than easy and fun things your shoes success.
# audio-chunks/chunk81.wav : To the monkey.
# audio-chunks/chunk82.wav : She wants just another animal species used to keep well swept welfare and propagating into the next generation.
# audio-chunks/chunk83.wav : Tribal time's my favourite ok but if you haven't noticed now we're not in tribal times we're in in advanced civilization in the monkey does not know what that is.
# audio-chunks/chunk84.wav : Which is why we have another guy her brain.
# audio-chunks/chunk85.wav : The rational decision maker.
# audio-chunks/chunk86.wav : Cookie the ability to do things no other animal can do we can visualise the future we can see the big picture.
# audio-chunks/chunk87.wav : We can make long-term plans if you want to take all of that into account.
# audio-chunks/chunk88.wav : Anyone's just have us do whatever makes sense to be doing right now that sometimes it makes sense to be doing things that are easy and fun like when you're having dinner going to better and join well and leisure time that's why there is an overlap sometimes they agree.
# audio-chunks/chunk89.wav : But other times it makes much more sense.
# audio-chunks/chunk90.wav : To be doing things.
# audio-chunks/chunk91.wav : There are harder and less pleasant for the sake of the big picture and that won't have a conflict.
# audio-chunks/chunk92.wav : Procrastinate that conflict end-to-end certain why every time leaving him spending a lot of time in this orange zone.
# audio-chunks/chunk93.wav : Easy and fun places entirely out of the makes sense circle i called the dark playground.
# Error:
# audio-chunks/chunk95.wav : Now.
# audio-chunks/chunk96.wav : The dark playground of the place that all of you procrastinators out there no very well.
# audio-chunks/chunk97.wav : Is there a leisure activities happen at thanks when we do activities are not supposed to be happening.
# audio-chunks/chunk98.wav : Fun you having a joke that isn't actually fun because it's completely unearned and they're still with gill.
# audio-chunks/chunk99.wav : Dread anxiety self hatred all those good procrastinator feelings.
# audio-chunks/chunk100.wav : The question is in this situation but the monkey behind the wheel had a suppressed there ever himself over here this blues.
# audio-chunks/chunk101.wav : A west pleasant place for a really important things happen.
# audio-chunks/chunk102.wav : Well.
# audio-chunks/chunk103.wav : Turns out.
# audio-chunks/chunk104.wav : The procrastinator has a guardian angel someone who's always looking down on him and watching over him.
# audio-chunks/chunk105.wav : In his darkest.
# audio-chunks/chunk106.wav : Someone called the panic monster.
# Error:
# audio-chunks/chunk108.wav : Now.
# audio-chunks/chunk109.wav : The panic monster is dormant most of the time.
# audio-chunks/chunk110.wav : Suddenly wakes up.
# audio-chunks/chunk111.wav : Any time deadline gets too close or there's danger public embarrassment disastrous another scary can't say.
# audio-chunks/chunk112.wav : And importantly he's the only thing that the monkey is terrified.
# audio-chunks/chunk113.wav : Now.
# audio-chunks/chunk114.wav : Keep aching very relevant in my life.
# Error:
# audio-chunks/chunk116.wav : Because people ted reached out to me about 6 months ago and invited me to do a ted talk.
# audio-chunks/chunk117.wav : Out of course i said yes it's always been a dream of mine to have done a ted talk in the past.
# Error:
# audio-chunks/chunk119.wav : Bring the excitement of rational decision-maker said has something else in his mind he was saying.
# audio-chunks/chunk120.wav : I'm what we just accepted.
# audio-chunks/chunk121.wav : What's going to be now happening one day in the future we need to sit down and work on the right now the monkey said totally agree just open google earth and department in dna 200 but the ground up to 1/2 hours till we get to the top of the country so we can get a better feel for india.
# Error:
# audio-chunks/chunk123.wav : So that's what we did that day.
# audio-chunks/chunk124.wav : Has six months turned into 4 and then 2 and 1 the people of ted decided to release the speakers and i open up the website and there is my face staring right back at me and guess who woke up.
# Error:
# audio-chunks/chunk126.wav : So the parrot man started using asthma.
# audio-chunks/chunk127.wav : A few seconds systems in may.
# audio-chunks/chunk128.wav : And the monkey remembers terrified of the tenth man he's up the tree.
# audio-chunks/chunk129.wav : I'm fine.
# audio-chunks/chunk130.wav : Finally the rational decision-making take the wheel and i can start working on the talk now.
# audio-chunks/chunk131.wav : Panic monster explain all kinds of.
# audio-chunks/chunk132.wav : Behaviour like how someone like me just been to.
# audio-chunks/chunk133.wav : Unable to start the opening sentence of a paper.
# audio-chunks/chunk134.wav : And then miraculously find the unbelievable work at 6 till all night and write 8 pages.
# audio-chunks/chunk135.wav : And this situation with the freak this is the procrastinators sister.
# audio-chunks/chunk136.wav : That pretty what is the end.
# Error:
# audio-chunks/chunk138.wav : And this is what i decided to write about i'm a blog.
# audio-chunks/chunk139.wav : Just a couple of years ago now when i did.
# audio-chunks/chunk140.wav : I was made by the.
# audio-chunks/chunk141.wav : What are the thousands of emails came in.
# audio-chunks/chunk142.wav : All different kinds of people from all over the world doing all different kinds of things.
# audio-chunks/chunk143.wav : Is there people ring nurses in becker's and painters and engineers.
# audio-chunks/chunk144.wav : They're already saying the same thing i have this problem too.
# audio-chunks/chunk145.wav : What struck me was the contrast between the light turn of the post.
# audio-chunks/chunk146.wav : And the heaviness of these emails.
# audio-chunks/chunk147.wav : This people.
# audio-chunks/chunk148.wav : Were reading with the tents for stressing about what procrastination is done to their life.
# audio-chunks/chunk149.wav : About with this monkey and don't of them.
# audio-chunks/chunk150.wav : And.
# audio-chunks/chunk151.wav : I thought about this and i said what's up across the resistor works then what's going on.
# audio-chunks/chunk152.wav : Why are the people feature dark place well.
# audio-chunks/chunk153.wav : Turn down the two kinds of procrastination.
# audio-chunks/chunk154.wav : Everything talked about today uk because of giving now have deadline deadline.
# audio-chunks/chunk155.wav : Do you fix procrastination or contain.
# audio-chunks/chunk156.wav : The short-term because the panic master gets involved but there's a second kind of request.
# audio-chunks/chunk157.wav : What happens in situations when there is no.
# audio-chunks/chunk158.wav : So you want to have a career you want to be a self-starter.
# audio-chunks/chunk159.wav : Entrepreneurial.
# audio-chunks/chunk160.wav : Because nothing's happening first not until you've gone out and done the hard work to get someone mental to get things go.
# audio-chunks/chunk161.wav : Rothwell council important things outside of your career that don't involve any deadlines i've seen your family you're exercising taking care of your health.
# audio-chunks/chunk162.wav : Working on your relationship or getting out of a relationship it isn't working.
# audio-chunks/chunk163.wav : L if.
# audio-chunks/chunk164.wav : Procrastinators only mechanism.
# audio-chunks/chunk165.wav : Doing these hard things is the panic monster that's a problem because in all these none deadline situations.
# audio-chunks/chunk166.wav : Pink matter doesn't show up you don't wake up for.
# audio-chunks/chunk167.wav : So the effects of procrastination do not contain extend outward forever.
# audio-chunks/chunk168.wav : Is this one kind of procrastination.
# audio-chunks/chunk169.wav : That's much less visible in which this talked about in the funniest short-term deadline based.
# audio-chunks/chunk170.wav : Is usually something quietly and privately.
# audio-chunks/chunk171.wav : Edit the source of a huge amount of long-term unhappy.
# audio-chunks/chunk172.wav : And regrets.
# audio-chunks/chunk173.wav : And i thought your dad's why these people are emailing and that's why they're in such a bad place.
# audio-chunks/chunk174.wav : Not the creamy for some.
# Error:
# audio-chunks/chunk176.wav : Procrastination is making feel like a spectator at times in their own lives.
# audio-chunks/chunk177.wav : Yeah the frustration was not they couldn't cheetah dreams that they were even able to start chasing them.
# audio-chunks/chunk178.wav : So.
# Error:
# audio-chunks/chunk180.wav : Read this email so i had a little bit of a pickle.
# Error:
# audio-chunks/chunk182.wav : I don't think non procrastinators exist.
# Error:
# audio-chunks/chunk184.wav : I think all you are procrastinators.
# audio-chunks/chunk185.wav : I'll be a mess.
# audio-chunks/chunk186.wav : Like some of us.
# audio-chunks/chunk187.wav : Some of you may have a healthy relationship with deadline.
# audio-chunks/chunk188.wav : Remember at the monkey's sneaky.
# audio-chunks/chunk189.wav : Trek is when the deadlines aren't there.
# audio-chunks/chunk190.wav : One last thing.
# audio-chunks/chunk191.wav : I called this.
# audio-chunks/chunk192.wav : A life challenge.
# audio-chunks/chunk193.wav : That's one box for every week.
# audio-chunks/chunk194.wav : €90 life.
# audio-chunks/chunk195.wav : How many boxes especially since.
# audio-chunks/chunk196.wav : Sorry use a bunch of those.
# audio-chunks/chunk197.wav : I think we need to all take a long hard.
# audio-chunks/chunk198.wav : That calendar.
# audio-chunks/chunk199.wav : We're thinking about what were really procrastinating and everyone is procrastinating on something in life.
# audio-chunks/chunk200.wav : We need to stay aware of the instant gratification monkey.
# audio-chunks/chunk201.wav : That's a job.
# audio-chunks/chunk202.wav : For all of us.
# audio-chunks/chunk203.wav : And because of that money back is on there to job that should probably start today.
# Error:
# audio-chunks/chunk205.wav : Today.
# audio-chunks/chunk206.wav : Shut up.
# audio-chunks/chunk207.wav : Sometimes.
# audio-chunks/chunk208.wav : Thanks.
# Error:
